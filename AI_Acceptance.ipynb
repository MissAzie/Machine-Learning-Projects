# %% [markdown]
# <a href="https://colab.research.google.com/github/MissAzie/Machine-Learning-Projects/blob/main/AI_Acceptance.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
import scipy.stats as stats
import statsmodels.api as sm
from statsmodels.formula.api import ols

# %%
# Load the dataset
data = pd.read_csv('data.csv')
data
# Out:
#      S/N  comfortable  transparency_decisions  social_media  Age
# 0      1            5                     3.0             2   26
# 1      2            5                     1.0             2   22
# 2      3            4                     1.0             1   64
# 3      4            4                     1.0             1   32
# 4      5            5                     2.0             2   22
# ..   ...          ...                     ...           ...  ...
# 312  313            4                     3.0             1   33
# 313  314            4                     5.0             1   22
# 314  315            3                     4.0             1   24
# 315  316            5                     4.0             2   26
# 316  317            4                     3.0             2   23
#
# [317 rows x 5 columns]

# %%
# Define the generational classification
def classify_generation(age):
    if 18 <= age <= 24:
        return "Generation Z"
    elif 25 <= age <= 40:
        return "Millennials"
    elif 41 <= age <= 56:
        return "Generation X"
    elif age >= 57:
        return "Baby Boomers"
    else:
        return "Unknown"

# %%
# Apply the classification to the Age column
df['Generation'] = df['Age'].apply(classify_generation)

# Check the first few rows to confirm the new column
print(df.head())
# Out:
#    S/N  comfortable  transparency_decisions  social_media  Age    Generation
# 0    1            5                     3.0             2   26   Millennials
# 1    2            5                     1.0             2   22  Generation Z
# 2    3            4                     1.0             1   64  Baby Boomers
# 3    4            4                     1.0             1   32   Millennials
# 4    5            5                     2.0             2   22  Generation Z

# %%
# Perform ANOVA analysis for a specific dependent variable, e.g., 'trust_privacy'
dependent_variable = 'comfortable'  # Replace with your DV column name
anova_df = df[['Generation', dependent_variable]].dropna()  # Drop NaN values

# %%
# Fit the ANOVA model
model = ols(f'{dependent_variable} ~ C(Generation)', data=anova_df).fit()
anova_table = sm.stats.anova_lm(model, typ=2)

# Print the ANOVA table
print("ANOVA Results:")
print(anova_table)
# Out:
# ANOVA Results:
#                    sum_sq     df         F    PR(>F)
# C(Generation)   14.941735    4.0  4.780568  0.000934
# Residual       243.790127  312.0       NaN       NaN
